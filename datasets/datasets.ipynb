# %% [markdown]
# ## IMDB Movies Dataset
#
# [Link to source](https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows)
# - Poster_Link - Link of the poster that imdb using
# - Series_Title = Name of the movie
# - Released_Year - Year at which that movie released
# - Certificate - Certificate earned by that movie
# - Runtime - Total runtime of the movie
# - Genre - Genre of the movie
# - IMDB_Rating - Rating of the movie at IMDB site
# - Overview - mini story/ summary
# - Meta_score - Score earned by the movie
# - Director - Name of the Director
# - Star1,Star2,Star3,Star4 - Name of the Stars
# - No_of_votes - Total number of votes
# - Gross - Money earned by that movie

# %%
import pandas as pd

# %%
df = pd.read_csv('imdb_top_1000.csv')
df.drop(['Poster_Link', 'Certificate', 'Meta_score', 'Director', 'No_of_Votes', 'Gross'], axis=1, inplace=True)

# rename columns to produce dictionary
df.rename(columns={'Series_Title': 'title'}, inplace=True)
df.rename(columns={'Released_Year': 'year'}, inplace=True)
df.rename(columns={'Runtime': 'runtime'}, inplace=True)
df.rename(columns={'Genre': 'genre'}, inplace=True)
df.rename(columns={'IMDB_Rating': 'rating'}, inplace=True)
df.rename(columns={'Overview': 'summary'}, inplace=True)

# replace content
df['runtime'].replace(to_replace=r'(\d*) min', value=r'\1', regex=True, inplace=True)
df['genre'].replace(r',', '', regex=True, inplace=True)
df['summary'].replace(r'[,.!?-]', '', regex=True, inplace=True)
df['actors'] = df[['Star1', 'Star2', 'Star3', 'Star4']].apply(lambda x: ' '.join(x), axis=1)
df['id'] = df.index + 1

# convert to target type
df['runtime'] = df['runtime'].astype(int)
df.drop(['Star1', 'Star2', 'Star3', 'Star4'], axis=1, inplace=True)

# reorder columns
df = df[['id', 'title', 'year', 'runtime', 'rating', 'genre', 'actors', 'summary']]

# show result
df.info()
df.to_dict('records')
# df['Genre'].unique()
# df[['Star1', 'Star2', 'Star3', 'Star4']].apply(lambda x: ' '.join(x), axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1000 non-null   int64
#  1   title    1000 non-null   object
#  2   year     1000 non-null   object
#  3   runtime  1000 non-null   int64
#  4   rating   1000 non-null   float64
#  5   genre    1000 non-null   object
#  6   actors   1000 non-null   object
#  7   summary  1000 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 62.6+ KB
# [{'id': 1,
#   'title': 'The Shawshank Redemption',
#   'year': '1994',
#   'runtime': 142,
#   'rating': 9.3,
#   'genre': 'Drama',
#   'actors': 'Tim Robbins Morgan Freeman Bob Gunton William Sadler',
#   'summary': 'Two imprisoned men bond over a number of years finding solace and eventual redemption through acts of common decency'},
#  {'id': 2,
#   'title': 'The Godfather',
#   'year': '1972',
#   'runtime': 175,
#   'rating': 9.2,
#   'genre': 'Crime Drama',
#   'actors': 'Marlon Brando Al Pacino James Caan Diane Keaton',
#   'summary': "An organized crime dynasty's aging patriarch transfers control of his clandestine empire to his reluctant son"},
#  {'id': 3,
#   'title': 'The Dark Knight',
#   'year': '2008',
#   'runtime': 152,
#   'rating': 9.0,
#   'genre': 'Action Crime Drama',
#   'actors': 'Christian Bale Heath Ledger Aaron Eckhart Michael Caine',
#   'summary': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice'},
#  {'id': 4,
#   'title': 'The Godfather: Part II',
#   'year': '1974',
#   'runtime': 202,
#   'rating': 9.0,
#   'genre': 'Crime Drama',
#   'actors': 'Al Pacino Robert De Niro Robert Duvall Diane Keaton',
#   'summary': 'The early life and career of Vito Corleone in 1920s New York City is portrayed while his son Michael expands and tightens his grip on the family crime syndicate'},
#  {'id': 5,
#   'title': '12 Angry Men',
#   'year': '1957',
#   'runtime': 96,
#   'rating': 9.0,
#   'genre': 'Crime Drama',
#   'actors': 'Henry Fonda Lee J. Cobb Martin Balsam John Fiedler',
#   'summary': 'A jury holdout attempts to prevent a miscarriage of justice by forcing his colleagues to reconsider the evidence'},
#  {'id': 6,
#   'title': 'The Lord of the Rings: The Return of the King',
#   'year': '2003',
#   'runtime': 201,
#   'rating': 8.9,
#   'genre': 'Action Adventure Drama',
#   'actors': 'Elijah Wood Viggo Mortensen Ian McKellen Orlando Bloom',
#   'summary': "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring"},
#  {'id': 7,
#   'title': 'Pulp Fiction',
#   'year': '1994',
#   'runtime': 154,
#   'rating': 8.9,
#   'genre': 'Crime Drama',
#   'actors': 'John Travolta Uma Thurman Samuel L. Jackson Bruce Willis',
#   'summary': 'The lives of two mob hitmen a boxer a gangster and his wife and a pair of diner bandits intertwine in four tales of violence and redemption'},
#  {'id': 8,
#   'title': "Schindler's List",
#   'year': '1993',
#   'runtime': 195,
#   'rating': 8.9,
#   'genre': 'Biography Drama History',
#   'actors': 'Liam Neeson Ralph Fiennes Ben Kingsley Caroline Goodall',
#   'summary': 'In Germanoccupied Poland during World War II industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis'},
#  {'id': 9,
#   'title': 'Inception',
#   'year': '2010',
#   'runtime': 148,
#   'rating': 8.8,
#   'genre': 'Action Adventure Sci-Fi',
#   'actors': 'Leonardo DiCaprio Joseph Gordon-Levitt Elliot Page Ken Watanabe',
#   'summary': 'A thief who steals corporate secrets through the use of dreamsharing technology is given the inverse task of planting an idea into the mind of a CEO'},
#  {'id': 10,
#   'title': 'Fight Club',
#   'year': '1999',
#   'runtime': 139,
#   'rating': 8.8,
#   'genre': 'Drama',
#   'actors': 'Brad Pitt Edward Norton Meat Loaf Zach Grenier',
#   'summary': 'An insomniac office worker and a devilmaycare soapmaker form an underground fight club that evolves into something much much more'},
#  {'id': 11,
#   'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'year': '2001',
#   'runtime': 178,
#   'rating': 8.8,
#   'genre': 'Action Adventure Drama',
#   'actors': 'Elijah Wood Ian McKellen Orlando Bloom Sean Bean',
#   'summary': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middleearth from the Dark Lord Sauron'},
#  {'id': 12,
#   'title': 'Forrest Gump',
#   'year': '1994',
#   'runtime': 142,
#   'rating': 8.8,
#   'genre': 'Drama Romance',
#   'actors': 'Tom Hanks Robin Wright Gary Sinise Sally Field',
#   'summary': 'The presidencies of Kennedy and Johnson the events of Vietnam Watergate and other historical events unfold through the perspective of an Alabama man with an IQ of 75 whose only desire is to be reunited with his childhood sweetheart'},
#  {'id': 13,
#   'title': 'Il buono, il brutto, il cattivo',
#   'year': '1966',
#   'runtime': 161,
#   'rating': 8.8,
#   'genre': 'Western',
#   'actors': 'Clint Eastwood Eli Wallach Lee Van Cleef Aldo Giuffrè',
#   'summary': 'A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery'},
#  {'id': 14,
#   'title': 'The Lord of the Rings: The Two Towers',
#   'year': '2002',
#   'runtime': 179,
#   'rating': 8.7,
#   'genre': 'Action Adventure Drama',
#   'actors': 'Elijah Wood Ian McKellen Viggo Mortensen Orlando Bloom',
#   'summary': "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum the divided fellowship makes a stand against Sauron's new ally Saruman and his hordes of Isengard"},
#  {'id': 15,
#   'title': 'The Matrix',
#   'year': '1999',
#   'runtime': 136,
#   'rating': 8.7,
#   'genre': 'Action Sci-Fi',
#   'actors': 'Lilly Wachowski Keanu Reeves Laurence Fishburne Carrie-Anne Moss',
#   'summary': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld he discovers the shocking truththe life he knows is the elaborate deception of an evil cyberintelligence'},
#  {'id': 16,
#   'title': 'Goodfellas',
#   'year': '1990',
#   'runtime': 146,
#   'rating': 8.7,
#   'genre': 'Biography Crime Drama',
#   'actors': 'Robert De Niro Ray Liotta Joe Pesci Lorraine Bracco',
#   'summary': 'The story of Henry Hill and his life in the mob covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito in the ItalianAmerican crime syndicate'},
#  {'id': 17,
#   'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'year': '1980',
#   'runtime': 124,
#   'rating': 8.7,
#   'genre': 'Action Adventure Fantasy',
#   'actors': 'Mark Hamill Harrison Ford Carrie Fisher Billy Dee Williams',
#   'summary': 'After the Rebels are brutally overpowered by the Empire on the ice planet Hoth Luke Skywalker begins Jedi training with Yoda while his friends are pursued by Darth Vader and a bounty hunter named Boba Fett all over the galaxy'},
#  {'id': 18,
#   'title': "One Flew Over the Cuckoo's Nest",
#   'year': '1975',
#   'runtime': 133,
#   'rating': 8.7,
#   'genre': 'Drama',
#   'actors': 'Jack Nicholson Louise Fletcher Michael Berryman Peter Brocco',
#   'summary': 'A criminal pleads insanity and is admitted to a mental institution where he rebels against the oppressive nurse and rallies up the scared patients'},
#  {'id': 19,
#   'title': 'Hamilton',
#   'year': '2020',
#   'runtime': 160,
#   'rating': 8.6,
#   'genre': 'Biography Drama History',
#   'actors': 'Lin-Manuel Miranda Phillipa Soo Leslie Odom Jr. Renée Elise Goldsberry',
#   'summary': "The real life of one of America's foremost founding fathers and first Secretary of the Treasury Alexander Hamilton Captured live on Broadway from the Richard Rodgers Theater with the original Broadway cast"},
#  {'id': 20,
#   'title': 'Gisaengchung',
#   'year': '2019',
#   'runtime': 132,
#   'rating': 8.6,
#   'genre': 'Comedy Drama Thriller',
#   'actors': 'Kang-ho Song Lee Sun-kyun Cho Yeo-jeong Choi Woo-sik',
#   'summary': 'Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan'},
#  {'id': 21,
#   'title': 'Soorarai Pottru',
#   'year': '2020',
#   'runtime': 153,
#   'rating': 8.6,
#   'genre': 'Drama',
#   'actors': 'Suriya Madhavan Paresh Rawal Aparna Balamurali',
#   'summary': 'Nedumaaran Rajangam "Maara" sets out to make the common man fly and in the process takes on the world\'s most capital intensive industry and several enemies who stand in his way'},
#  {'id': 22,
#   'title': 'Interstellar',
#   'year': '2014',
#   'runtime': 169,
#   'rating': 8.6,
#   'genre': 'Adventure Drama Sci-Fi',
#   'actors': 'Matthew McConaughey Anne Hathaway Jessica Chastain Mackenzie Foy',
#   'summary': "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival"},
#  {'id': 23,
#   'title': 'Cidade de Deus',
#   'year': '2002',
#   'runtime': 130,
#   'rating': 8.6,
#   'genre': 'Crime Drama',
#   'actors': 'Kátia Lund Alexandre Rodrigues Leandro Firmino Matheus Nachtergaele',
#   'summary': "In the slums of Rio two kids' paths diverge as one struggles to become a photographer and the other a kingpin"},
#  {'id': 24,
#   'title': 'Sen to Chihiro no kamikakushi',
#   'year': '2001',
#   'runtime': 125,
#   'rating': 8.6,
#   'genre': 'Animation Adventure Family',
#   'actors': 'Daveigh Chase Suzanne Pleshette Miyu Irino Rumi Hiiragi',
#   'summary': "During her family's move to the suburbs a sullen 10yearold girl wanders into a world ruled by gods witches and spirits and where humans are changed into beasts"},
#  {'id': 25,
#   'title': 'Saving Private Ryan',
#   'year': '1998',
#   'runtime': 169,
#   'rating': 8.6,
#   'genre': 'Drama War',
#   'actors': 'Tom Hanks Matt Damon Tom Sizemore Edward Burns',
#   'summary': 'Following the Normandy Landings a group of US soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action'},
#  {'id': 26,
#   'title': 'The Green Mile',
#   'year': '1999',
#   'runtime': 189,
#   'rating': 8.6,
#   'genre': 'Crime Drama Fantasy',
#   'actors': 'Tom Hanks Michael Clarke Duncan David Morse Bonnie Hunt',
#   'summary': 'The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape yet who has a mysterious gift'},
#  {'id': 27,
#   'title': 'La vita è bella',
#   'year': '1997',
#   'runtime': 116,
#   'rating': 8.6,
#   'genre': 'Comedy Drama Romance',
#   'actors': 'Roberto Benigni Nicoletta Braschi Giorgio Cantarini Giustino Durano',
#   'summary': 'When an openminded Jewish librarian and his son become victims of the Holocaust he uses a perfect mixture of will humor and imagination to protect his son from the dangers around their camp'},
#  {'id': 28,
#   'title': 'Se7en',
#   'year': '1995',
#   'runtime': 127,
#   'rating': 8.6,
#   'genre': 'Crime Drama Mystery',
#   'actors': 'Morgan Freeman Brad Pitt Kevin Spacey Andrew Kevin Walker',
#   'summary': 'Two detectives a rookie and a veteran hunt a serial killer who uses the seven deadly sins as his motives'},
#  {'id': 29,
#   'title': 'The Silence of the Lambs',
#   'year': '1991',
#   'runtime': 118,
#   'rating': 8.6,
#   'genre': 'Crime Drama Thriller',
#   'actors': 'Jodie Foster Anthony Hopkins Lawrence A. Bonney Kasi Lemmons',
#   'summary': 'A young FBI cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer a madman who skins his victims'},
#  {'id': 30,
#   'title': 'Star Wars',
#   'year': '1977',
#   'runtime': 121,
#   'rating': 8.6,
#   'genre': 'Action Adventure Fantasy',
#   'actors': 'Mark Hamill Harrison Ford Carrie Fisher Alec Guinness',
#   'summary': "Luke Skywalker joins forces with a Jedi Knight a cocky pilot a Wookiee and two droids to save the galaxy from the Empire's worlddestroying battle station while also attempting to rescue Princess Leia from the mysterious Darth Vader"},
#  {'id': 31,
#   'title': 'Seppuku',
#   'year': '1962',
#   'runtime': 133,
#   'rating': 8.6,
#   'genre': 'Action Drama Mystery',
#   'actors': 'Tatsuya Nakadai Akira Ishihama Shima Iwashita Tetsurô Tanba',
#   'summary': "When a ronin requesting seppuku at a feudal lord's palace is told of the brutal suicide of another ronin who previously visited he reveals how their pasts are intertwined  and in doing so challenges the clan's integrity"},
#  {'id': 32,
#   'title': 'Shichinin no samurai',
#   'year': '1954',
#   'runtime': 207,
#   'rating': 8.6,
#   'genre': 'Action Adventure Drama',
#   'actors': 'Toshirô Mifune Takashi Shimura Keiko Tsushima Yukiko Shimazaki',
#   'summary': 'A poor village under attack by bandits recruits seven unemployed samurai to help them defend themselves'},
#  {'id': 33,
#   'title': "It's a Wonderful Life",
#   'year': '1946',
#   'runtime': 130,
#   'rating': 8.6,
#   'genre': 'Drama Family Fantasy',
#   'actors': 'James Stewart Donna Reed Lionel Barrymore Thomas Mitchell',
#   'summary': 'An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed'},
#  {'id': 34,
#   'title': 'Joker',
#   'year': '2019',
#   'runtime': 122,
#   'rating': 8.5,
#   'genre': 'Crime Drama Thriller',
#   'actors': 'Joaquin Phoenix Robert De Niro Zazie Beetz Frances Conroy',
#   'summary': 'In Gotham City mentally troubled comedian Arthur Fleck is disregarded and mistreated by society He then embarks on a downward spiral of revolution and bloody crime This path brings him facetoface with his alterego: the Joker'},
#  {'id': 35,
#   'title': 'Whiplash',
#   'year': '2014',
#   'runtime': 106,
#   'rating': 8.5,
#   'genre': 'Drama Music',
#   'actors': 'Miles Teller J.K. Simmons Melissa Benoist Paul Reiser',
#   'summary': "A promising young drummer enrolls at a cutthroat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential"},
#  {'id': 36,
#   'title': 'The Intouchables',
#   'year': '2011',
#   'runtime': 112,
#   'rating': 8.5,
#   'genre': 'Biography Comedy Drama',
#   'actors': 'Éric Toledano François Cluzet Omar Sy Anne Le Ny',
#   'summary': 'After he becomes a quadriplegic from a paragliding accident an aristocrat hires a young man from the projects to be his caregiver'},
#  {'id': 37,
#   'title': 'The Prestige',
#   'year': '2006',
#   'runtime': 130,
#   'rating': 8.5,
#   'genre': 'Drama Mystery Sci-Fi',
#   'actors': 'Christian Bale Hugh Jackman Scarlett Johansson Michael Caine',
#   'summary': 'After a tragic accident two stage magicians engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other'},
#  {'id': 38,
#   'title': 'The Departed',
#   'year': '2006',
#   'runtime': 151,
#   'rating': 8.5,
#   'genre': 'Crime Drama Thriller',
#   'actors': 'Leonardo DiCaprio Matt Damon Jack Nicholson Mark Wahlberg',
#   'summary': 'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston'},
#  {'id': 39,
#   'title': 'The Pianist',
#   'year': '2002',
#   'runtime': 150,
#   'rating': 8.5,
#   'genre': 'Biography Drama Music',
#   'actors': 'Adrien Brody Thomas Kretschmann Frank Finlay Emilia Fox',
#   'summary': 'A Polish Jewish musician struggles to survive the destruction of the Warsaw ghetto of World War II'},
#  {'id': 40,
#   'title': 'Gladiator',
#   'year': '2000',
#   'runtime': 155,
#   'rating': 8.5,
#   'genre': 'Action Adventure Drama',
#   'actors': 'Russell Crowe Joaquin Phoenix Connie Nielsen Oliver Reed',
#   'summary': 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery'},
#  {'id': 41,
#   'title': 'American History X',
#   'year': '1998',
#   'runtime': 119,
#   'rating': 8.5,
#   'genre': 'Drama',
#   'actors': "Edward Norton Edward Furlong Beverly D'Angelo Jennifer Lien",
#   'summary': 'A former neonazi skinhead tries to prevent his younger brother from going down the same wrong path that he did'},
#  {'id': 42,
#   'title': 'The Usual Suspects',
#   'year': '1995',
#   'runtime': 106,
#   'rating': 8.5,
#   'genre': 'Crime Mystery Thriller',
#   'actors': 'Kevin Spacey Gabriel Byrne Chazz Palminteri Stephen Baldwin',
#   'summary': 'A sole survivor tells of the twisty events leading up to a horrific gun battle on a boat which began when five criminals met at a seemingly random police lineup'},
#  {'id': 43,
#   'title': 'Léon',
#   'year': '1994',
#   'runtime': 110,
#   'rating': 8.5,
#   'genre': 'Action Crime Drama',
#   'actors': 'Jean Reno Gary Oldman Natalie Portman Danny Aiello',
#   'summary': "Mathilda a 12yearold girl is reluctantly taken in by Léon a professional assassin after her family is murdered An unusual relationship forms as she becomes his protégée and learns the assassin's trade"},
#  {'id': 44,
#   'title': 'The Lion King',
#   'year': '1994',
#   'runtime': 88,
#   'rating': 8.5,
#   'genre': 'Animation Adventure Drama',
#   'actors': 'Rob Minkoff Matthew Broderick Jeremy Irons James Earl Jones',
#   'summary': 'Lion prince Simba and his father are targeted by his bitter uncle who wants to ascend the throne himself'},
#  {'id': 45,
#   'title': 'Terminator 2: Judgment Day',
#   'year': '1991',
#   'runtime': 137,
#   'rating': 8.5,
#   'genre': 'Action Sci-Fi',
#   'actors': 'Arnold Schwarzenegger Linda Hamilton Edward Furlong Robert Patrick',
#   'summary': 'A cyborg identical to the one who failed to kill Sarah Connor must now protect her teenage son John Connor from a more advanced and powerful cyborg'},
#  {'id': 46,
#   'title': 'Nuovo Cinema Paradiso',
#   'year': '1988',
#   'runtime': 155,
#   'rating': 8.5,
#   'genre': 'Drama Romance',
#   'actors': 'Philippe Noiret Enzo Cannavale Antonella Attili Isa Danieli',
#   'summary': "A filmmaker recalls his childhood when falling in love with the pictures at the cinema of his home village and forms a deep friendship with the cinema's projectionist"},
#  {'id': 47,
#   'title': 'Hotaru no haka',
#   'year': '1988',
#   'runtime': 89,
#   'rating': 8.5,
#   'genre': 'Animation Drama War',
#   'actors': 'Tsutomu Tatsumi Ayano Shiraishi Akemi Yamaguchi Yoshiko Shinohara',
#   'summary': 'A young boy and his little sister struggle to survive in Japan during World War II'},
#  {'id': 48,
#   'title': 'Back to the Future',
#   'year': '1985',
#   'runtime': 116,
#   'rating': 8.5,
#   'genre': 'Adventure Comedy Sci-Fi',
#   'actors': 'Michael J. Fox Christopher Lloyd Lea Thompson Crispin Glover',
#   'summary': 'Marty McFly a 17yearold high school student is accidentally sent thirty years into the past in a timetraveling DeLorean invented by his close friend the eccentric scientist Doc Brown'},
#  {'id': 49,
#   'title': 'Once Upon a Time in the West',
#   'year': '1968',
#   'runtime': 165,
#   'rating': 8.5,
#   'genre': 'Western',
#   'actors': 'Henry Fonda Charles Bronson Claudia Cardinale Jason Robards',
#   'summary': 'A mysterious stranger with a harmonica joins forces with a notorious desperado to protect a beautiful widow from a ruthless assassin working for the railroad'},
#  {'id': 50,
#   'title': 'Psycho',
#   'year': '1960',
#   'runtime': 109,
#   'rating': 8.5,
#   'genre': 'Horror Mystery Thriller',
#   'actors': 'Anthony Perkins Janet Leigh Vera Miles John Gavin',
#   'summary': "A Phoenix secretary embezzles $40000 from her employer's client goes on the run and checks into a remote motel run by a young man under the domination of his mother"},
#  {'id': 51,
#   'title': 'Casablanca',
#   'year': '1942',
#   'runtime': 102,
#   'rating': 8.5,
#   'genre': 'Drama Romance War',
#   'actors': 'Humphrey Bogart Ingrid Bergman Paul Henreid Claude Rains',
#   'summary': 'A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitive husband escape the Nazis in French Morocco'},
#  {'id': 52,
#   'title': 'Modern Times',
#   'year': '1936',
#   'runtime': 87,
#   'rating': 8.5,
#   'genre': 'Comedy Drama Family',
#   'actors': 'Charles Chaplin Paulette Goddard Henry Bergman Tiny Sandford',
#   'summary': 'The Tramp struggles to live in modern industrial society with the help of a young homeless woman'},
#  {'id': 53,
#   'title': 'City Lights',
#   'year': '1931',
#   'runtime': 87,
#   'rating': 8.5,
#   'genre': 'Comedy Drama Romance',
#   'actors': 'Charles Chaplin Virginia Cherrill Florence Lee Harry Myers',
#   'summary': 'With the aid of a wealthy erratic tippler a dewyeyed tramp who has fallen in love with a sightless flower girl accumulates money to be able to help her medically'},
#  {'id': 54,
#   'title': 'Capharnaüm',
#   'year': '2018',
#   'runtime': 126,
#   'rating': 8.4,
#   'genre': 'Drama',
#   'actors': 'Zain Al Rafeea Yordanos Shiferaw Boluwatife Treasure Bankole Kawsar Al Haddad',
#   'summary': 'While serving a fiveyear sentence for a violent crime a 12yearold boy sues his parents for neglect'},
#  {'id': 55,
#   'title': 'Ayla: The Daughter of War',
#   'year': '2017',
#   'runtime': 125,
#   'rating': 8.4,
#   'genre': 'Biography Drama History',
#   'actors': 'Erdem Can Çetin Tekindor Ismail Hacioglu Kyung-jin Lee',
#   'summary': 'In 1950 amidst the ravages of the Korean War Sergeant Süleyman stumbles upon a halffrozen little girl with no parents and no help in sight Frantic scared and on the verge of death                 See full summary\xa0»'},
#  {'id': 56,
#   'title': 'Vikram Vedha',
#   'year': '2017',
#   'runtime': 147,
#   'rating': 8.4,
#   'genre': 'Action Crime Drama',
#   'actors': 'Pushkar Madhavan Vijay Sethupathi Shraddha Srinath',
#   'summary': "Vikram a nononsense police officer accompanied by Simon his partner is on the hunt to capture Vedha a smuggler and a murderer Vedha tries to change Vikram's life which leads to a conflict"},
#  {'id': 57,
#   'title': 'Kimi no na wa.',
#   'year': '2016',
#   'runtime': 106,
#   'rating': 8.4,
#   'genre': 'Animation Drama Fantasy',
#   'actors': 'Ryûnosuke Kamiki Mone Kamishiraishi Ryô Narita Aoi Yûki',
#   'summary': 'Two strangers find themselves linked in a bizarre way When a connection forms will distance be the only thing to keep them apart'},
#  {'id': 58,
#   'title': 'Dangal',
#   'year': '2016',
#   'runtime': 161,
#   'rating': 8.4,
#   'genre': 'Action Biography Drama',
#   'actors': 'Aamir Khan Sakshi Tanwar Fatima Sana Shaikh Sanya Malhotra',
#   'summary': 'Former wrestler Mahavir Singh Phogat and his two wrestler daughters struggle towards glory at the Commonwealth Games in the face of societal oppression'},
#  {'id': 59,
#   'title': 'Spider-Man: Into the Spider-Verse',
#   'year': '2018',
#   'runtime': 117,
#   'rating': 8.4,
#   'genre': 'Animation Action Adventure',
#   'actors': 'Peter Ramsey Rodney Rothman Shameik Moore Jake Johnson',
#   'summary': 'Teen Miles Morales becomes the SpiderMan of his universe and must join with five spiderpowered individuals from other dimensions to stop a threat for all realities'},
#  {'id': 60,
#   'title': 'Avengers: Endgame',
#   'year': '2019',
#   'runtime': 181,
#   'rating': 8.4,
#   'genre': 'Action Adventure Drama',
#   'actors': 'Joe Russo Robert Downey Jr. Chris Evans Mark Ruffalo',
#   'summary': "After the devastating events of Avengers: Infinity War (2018) the universe is in ruins With the help of remaining allies the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe"},
#  {'id': 61,
#   'title': 'Avengers: Infinity War',
#   'year': '2018',
#   'runtime': 149,
#   'rating': 8.4,
#   'genre': 'Action Adventure Sci-Fi',
#   'actors': 'Joe Russo Robert Downey Jr. Chris Hemsworth Mark Ruffalo',
#   'summary': 'The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe'},
#  {'id': 62,
#   'title': 'Coco',
#   'year': '2017',
#   'runtime': 105,
#   'rating': 8.4,
#   'genre': 'Animation Adventure Family',
#   'actors': 'Adrian Molina Anthony Gonzalez Gael García Bernal Benjamin Bratt',
#   'summary': "Aspiring musician Miguel confronted with his family's ancestral ban on music enters the Land of the Dead to find his greatgreatgrandfather a legendary singer"},
#  {'id': 63,
#   'title': 'Django Unchained',
#   'year': '2012',
#   'runtime': 165,
#   'rating': 8.4,
#   'genre': 'Drama Western',
#   'actors': 'Jamie Foxx Christoph Waltz Leonardo DiCaprio Kerry Washington',
#   'summary': 'With the help of a German bounty hunter a freed slave sets out to rescue his wife from a brutal Mississippi plantation owner'},
#  {'id': 64,
#   'title': 'The Dark Knight Rises',
#   'year': '2012',
#   'runtime': 164,
#   'rating': 8.4,
#   'genre': 'Action Adventure',
#   'actors': 'Christian Bale Tom Hardy Anne Hathaway Gary Oldman',
#   'summary': "Eight years after the Joker's reign of anarchy Batman with the help of the enigmatic Catwoman is forced from his exile to save Gotham City from the brutal guerrilla terrorist Bane"},
#  {'id': 65,
#   'title': '3 Idiots',
#   'year': '2009',
#   'runtime': 170,
#   'rating': 8.4,
#   'genre': 'Comedy Drama',
#   'actors': 'Aamir Khan Madhavan Mona Singh Sharman Joshi',
#   'summary': 'Two friends are searching for their long lost companion They revisit their college days and recall the memories of their friend who inspired them to think differently even as the rest of the world called them "idiots"'},
#  {'id': 66,
#   'title': 'Taare Zameen Par',
#   'year': '2007',
#   'runtime': 165,
#   'rating': 8.4,
#   'genre': 'Drama Family',
#   'actors': 'Amole Gupte Darsheel Safary Aamir Khan Tisca Chopra',
#   'summary': 'An eightyearold boy is thought to be a lazy troublemaker until the new art teacher has the patience and compassion to discover the real problem behind his struggles in school'},
#  {'id': 67,
#   'title': 'WALL·E',
#   'year': '2008',
#   'runtime': 98,
#   'rating': 8.4,
#   'genre': 'Animation Adventure Family',
#   'actors': 'Ben Burtt Elissa Knight Jeff Garlin Fred Willard',
#   'summary': 'In the distant future a small wastecollecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind'},
#  {'id': 68,
#   'title': 'The Lives of Others',
#   'year': '2006',
#   'runtime': 137,
#   'rating': 8.4,
#   'genre': 'Drama Mystery Thriller',
#   'actors': 'Ulrich Mühe Martina Gedeck Sebastian Koch Ulrich Tukur',
#   'summary': 'In 1984 East Berlin an agent of the secret police conducting surveillance on a writer and his lover finds himself becoming increasingly absorbed by their lives'},
#  {'id': 69,
#   'title': 'Oldeuboi',
#   'year': '2003',
#   'runtime': 101,
#   'rating': 8.4,
#   'genre': 'Action Drama Mystery',
#   'actors': 'Choi Min-sik Yoo Ji-Tae Kang Hye-jeong Kim Byeong-Ok',
#   'summary': 'After being kidnapped and imprisoned for fifteen years Oh DaeSu is released only to find that he must find his captor in five days'},
#  {'id': 70,
#   'title': 'Memento',
#   'year': '2000',
#   'runtime': 113,
#   'rating': 8.4,
#   'genre': 'Mystery Thriller',
#   'actors': 'Guy Pearce Carrie-Anne Moss Joe Pantoliano Mark Boone Junior',
#   'summary': "A man with shortterm memory loss attempts to track down his wife's murderer"},
#  {'id': 71,
#   'title': 'Mononoke-hime',
#   'year': '1997',
#   'runtime': 134,
#   'rating': 8.4,
#   'genre': 'Animation Action Adventure',
#   'actors': 'Yôji Matsuda Yuriko Ishida Yûko Tanaka Billy Crudup',
#   'summary': "On a journey to find the cure for a Tatarigami's curse Ashitaka finds himself in the middle of a war between the forest gods and Tatara a mining colony In this quest he also meets San the Mononoke Hime"},
#  {'id': 72,
#   'title': 'Once Upon a Time in America',
#   'year': '1984',
#   'runtime': 229,
#   'rating': 8.4,
#   'genre': 'Crime Drama',
#   'actors': 'Robert De Niro James Woods Elizabeth McGovern Treat Williams',
#   'summary': 'A former Prohibitionera Jewish gangster returns to the Lower East Side of Manhattan over thirty years later where he once again must confront the ghosts and regrets of his old life'},
#  {'id': 73,
#   'title': 'Raiders of the Lost Ark',
#   'year': '1981',
#   'runtime': 115,
#   'rating': 8.4,
#   'genre': 'Action Adventure',
#   'actors': 'Harrison Ford Karen Allen Paul Freeman John Rhys-Davies',
#   'summary': "In 1936 archaeologist and adventurer Indiana Jones is hired by the US government to find the Ark of the Covenant before Adolf Hitler's Nazis can obtain its awesome powers"},
#  {'id': 74,
#   'title': 'The Shining',
#   'year': '1980',
#   'runtime': 146,
#   'rating': 8.4,
#   'genre': 'Drama Horror',
#   'actors': 'Jack Nicholson Shelley Duvall Danny Lloyd Scatman Crothers',
#   'summary': 'A family heads to an isolated hotel for the winter where a sinister presence influences the father into violence while his psychic son sees horrific forebodings from both past and future'},
#  {'id': 75,
#   'title': 'Apocalypse Now',
#   'year': '1979',
#   'runtime': 147,
#   'rating': 8.4,
#   'genre': 'Drama Mystery War',
#   'actors': 'Martin Sheen Marlon Brando Robert Duvall Frederic Forrest',
#   'summary': 'A US Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god'},
#  {'id': 76,
#   'title': 'Alien',
#   'year': '1979',
#   'runtime': 117,
#   'rating': 8.4,
#   'genre': 'Horror Sci-Fi',
#   'actors': 'Sigourney Weaver Tom Skerritt John Hurt Veronica Cartwright',
#   'summary': 'After a space merchant vessel receives an unknown transmission as a distress call one of the crew is attacked by a mysterious life form and they soon realize that its life cycle has merely begun'},
#  {'id': 77,
#   'title': 'Anand',
#   'year': '1971',
#   'runtime': 122,
#   'rating': 8.4,
#   'genre': 'Drama Musical',
#   'actors': 'Rajesh Khanna Amitabh Bachchan Sumita Sanyal Ramesh Deo',
#   'summary': 'The story of a terminally ill man who wishes to live life to the fullest before the inevitable occurs as told by his best friend'},
#  {'id': 78,
#   'title': 'Tengoku to jigoku',
#   'year': '1963',
#   'runtime': 143,
#   'rating': 8.4,
#   'genre': 'Crime Drama Mystery',
#   'actors': 'Toshirô Mifune Yutaka Sada Tatsuya Nakadai Kyôko Kagawa',
#   'summary': "An executive of a shoe company becomes a victim of extortion when his chauffeur's son is kidnapped and held for ransom"},
#  {'id': 79,
#   'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'year': '1964',
#   'runtime': 95,
#   'rating': 8.4,
#   'genre': 'Comedy',
#   'actors': 'Peter Sellers George C. Scott Sterling Hayden Keenan Wynn',
#   'summary': 'An insane general triggers a path to nuclear holocaust that a War Room full of politicians and generals frantically tries to stop'},
#  {'id': 80,
#   'title': 'Witness for the Prosecution',
#   'year': '1957',
#   'runtime': 116,
#   'rating': 8.4,
#   'genre': 'Crime Drama Mystery',
#   'actors': 'Tyrone Power Marlene Dietrich Charles Laughton Elsa Lanchester',
#   'summary': 'A veteran British barrister must defend his client in a murder trial that has surprise after surprise'},
#  {'id': 81,
#   'title': 'Paths of Glory',
#   'year': '1957',
#   'runtime': 88,
#   'rating': 8.4,
#   'genre': 'Drama War',
#   'actors': 'Kirk Douglas Ralph Meeker Adolphe Menjou George Macready',
#   'summary': 'After refusing to attack an enemy position a general accuses the soldiers of cowardice and their commanding officer must defend them'},
#  {'id': 82,
#   'title': 'Rear Window',
#   'year': '1954',
#   'runtime': 112,
#   'rating': 8.4,
#   'genre': 'Mystery Thriller',
#   'actors': 'James Stewart Grace Kelly Wendell Corey Thelma Ritter',
#   'summary': 'A wheelchairbound photographer spies on his neighbors from his apartment window and becomes convinced one of them has committed murder'},
#  {'id': 83,
#   'title': 'Sunset Blvd.',
#   'year': '1950',
#   'runtime': 110,
#   'rating': 8.4,
#   'genre': 'Drama Film-Noir',
#   'actors': 'William Holden Gloria Swanson Erich von Stroheim Nancy Olson',
#   'summary': 'A screenwriter develops a dangerous relationship with a faded film star determined to make a triumphant return'},
#  {'id': 84,
#   'title': 'The Great Dictator',
#   'year': '1940',
#   'runtime': 125,
#   'rating': 8.4,
#   'genre': 'Comedy Drama War',
#   'actors': 'Charles Chaplin Paulette Goddard Jack Oakie Reginald Gardiner',
#   'summary': "Dictator Adenoid Hynkel tries to expand his empire while a poor Jewish barber tries to avoid persecution from Hynkel's regime"},
#  {'id': 85,
#   'title': '1917',
#   'year': '2019',
#   'runtime': 119,
#   'rating': 8.3,
#   'genre': 'Drama Thriller War',
#   'actors': 'Dean-Charles Chapman George MacKay Daniel Mays Colin Firth',
#   'summary': 'April 6th 1917 As a regiment assembles to wage war deep in enemy territory two soldiers are assigned to race against time and deliver a message that will stop 1600 men from walking straight into a deadly trap'},
#  {'id': 86,
#   'title': 'Tumbbad',
#   'year': '2018',
#   'runtime': 104,
#   'rating': 8.3,
#   'genre': 'Drama Fantasy Horror',
#   'actors': 'Anand Gandhi Adesh Prasad Sohum Shah Jyoti Malshe',
#   'summary': 'A mythological story about a goddess who created the entire universe The plot revolves around the consequences when humans build a temple for her firstborn'},
#  {'id': 87,
#   'title': 'Andhadhun',
#   'year': '2018',
#   'runtime': 139,
#   'rating': 8.3,
#   'genre': 'Crime Drama Music',
#   'actors': 'Ayushmann Khurrana Tabu Radhika Apte Anil Dhawan',
#   'summary': 'A series of mysterious events change the life of a blind pianist who must now report a crime that he should technically know nothing of'},
#  {'id': 88,
#   'title': 'Drishyam',
#   'year': '2013',
#   'runtime': 160,
#   'rating': 8.3,
#   'genre': 'Crime Drama Thriller',
#   'actors': 'Mohanlal Meena Asha Sharath Ansiba',
#   'summary': 'A man goes to extreme lengths to save his family from punishment after the family commits an accidental crime'},
#  {'id': 89,
#   'title': 'Jagten',
#   'year': '2012',
#   'runtime': 115,
#   'rating': 8.3,
#   'genre': 'Drama',
#   'actors': 'Mads Mikkelsen Thomas Bo Larsen Annika Wedderkopp Lasse Fogelstrøm',
#   'summary': "A teacher lives a lonely life all the while struggling over his son's custody His life slowly gets better as he finds love and receives good news from his son but his new luck is about to be brutally shattered by an innocent little lie"},
#  {'id': 90,
#   'title': 'Jodaeiye Nader az Simin',
#   'year': '2011',
#   'runtime': 123,
#   'rating': 8.3,
#   'genre': 'Drama',
#   'actors': 'Payman Maadi Leila Hatami Sareh Bayat Shahab Hosseini',
#   'summary': "A married couple are faced with a difficult decision  to improve the life of their child by moving to another country or to stay in Iran and look after a deteriorating parent who has Alzheimer's disease"},
#  {'id': 91,
#   'title': 'Incendies',
#   'year': '2010',
#   'runtime': 131,
#   'rating': 8.3,
#   'genre': 'Drama Mystery War',
#   'actors': 'Lubna Azabal Mélissa Désormeaux-Poulin Maxim Gaudette Mustafa Kamel',
#   'summary': "Twins journey to the Middle East to discover their family history and fulfill their mother's last wishes"},
#  {'id': 92,
#   'title': 'Miracle in cell NO.7',
#   'year': '2019',
#   'runtime': 132,
#   'rating': 8.3,
#   'genre': 'Drama',
#   'actors': 'Aras Bulut Iynemli Nisa Sofiya Aksongur Deniz Baysal Celile Toyon Uysal',
#   'summary': 'A story of love between a mentallyill father who was wrongly accused of murder and his lovely six years old daughter The prison would be their home Based on the 2013 Korean movie 7beonbangui seonmul (2013)'},
#  {'id': 93,
#   'title': 'Babam ve Oglum',
#   'year': '2005',
#   'runtime': 112,
#   'rating': 8.3,
#   'genre': 'Drama Family',
#   'actors': 'Çetin Tekindor Fikret Kuskan Hümeyra Ege Tanman',
#   'summary': 'The family of a leftwing journalist is torn apart after the military coup of Turkey in 1980'},
#  {'id': 94,
#   'title': 'Inglourious Basterds',
#   'year': '2009',
#   'runtime': 153,
#   'rating': 8.3,
#   'genre': 'Adventure Drama War',
#   'actors': 'Brad Pitt Diane Kruger Eli Roth Mélanie Laurent',
#   'summary': "In Nazioccupied France during World War II a plan to assassinate Nazi leaders by a group of Jewish US soldiers coincides with a theatre owner's vengeful plans for the same"},
#  {'id': 95,
#   'title': 'Eternal Sunshine of the Spotless Mind',
#   'year': '2004',
#   'runtime': 108,
#   'rating': 8.3,
#   'genre': 'Drama Romance Sci-Fi',
#   'actors': 'Jim Carrey Kate Winslet Tom Wilkinson Gerry Robert Byrne',
#   'summary': 'When their relationship turns sour a couple undergoes a medical procedure to have each other erased from their memories'},
#  {'id': 96,
#   'title': 'Amélie',
#   'year': '2001',
#   'runtime': 122,
#   'rating': 8.3,
#   'genre': 'Comedy Romance',
#   'actors': 'Audrey Tautou Mathieu Kassovitz Rufus Lorella Cravotta',
#   'summary': 'Amélie is an innocent and naive girl in Paris with her own sense of justice She decides to help those around her and along the way discovers love'},
#  {'id': 97,
#   'title': 'Snatch',
#   'year': '2000',
#   'runtime': 104,
#   'rating': 8.3,
#   'genre': 'Comedy Crime',
#   'actors': 'Jason Statham Brad Pitt Benicio Del Toro Dennis Farina',
#   'summary': 'Unscrupulous boxing promoters violent bookmakers a Russian gangster incompetent amateur robbers and supposedly Jewish jewelers fight to track down a priceless stolen diamond'},
#  {'id': 98,
#   'title': 'Requiem for a Dream',
#   'year': '2000',
#   'runtime': 102,
#   'rating': 8.3,
#   'genre': 'Drama',
#   'actors': 'Ellen Burstyn Jared Leto Jennifer Connelly Marlon Wayans',
#   'summary': 'The druginduced utopias of four Coney Island people are shattered when their addictions run deep'},
#  {'id': 99,
#   'title': 'American Beauty',
#   'year': '1999',
#   'runtime': 122,
#   'rating': 8.3,
#   'genre': 'Drama',
#   'actors': 'Kevin Spacey Annette Bening Thora Birch Wes Bentley',
#   'summary': "A sexually frustrated suburban father has a midlife crisis after becoming infatuated with his daughter's best friend"},
#  {'id': 100,
#   'title': 'Good Will Hunting',
#   'year': '1997',
#   'runtime': 126,
#   'rating': 8.3,
#   'genre': 'Drama Romance',
#   'actors': 'Robin Williams Matt Damon Ben Affleck Stellan Skarsgård',
#   'summary': 'Will Hunting a janitor at MIT has a gift for mathematics but needs help from a psychologist to find direction in his life'},
#  {'id': 101,
#   'title': 'Bacheha-Ye aseman',
#   'year': '1997',
#   'runtime': 89,
#   'rating': 8.3,
#   'genre': 'Drama Family Sport',
#   'actors': 'Mohammad Amir Naji Amir Farrokh Hashemian Bahare Seddiqi Nafise Jafar-Mohammadi',
#   'summary': 'After a boy loses his sister\'s pair of shoes he goes on a series of adventures in order to find them When he can\'t he tries a new way to "win" a new pair'},
#  {'id': 102,
#   'title': 'Toy Story',
#   'year': '1995',
#   'runtime': 81,
#   'rating': 8.3,
#   'genre': 'Animation Adventure Comedy',
#   'actors': 'Tom Hanks Tim Allen Don Rickles Jim Varney',
#   'summary': "A cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room"},
#  {'id': 103,
#   'title': 'Braveheart',
#   'year': '1995',
#   'runtime': 178,
#   'rating': 8.3,
#   'genre': 'Biography Drama History',
#   'actors': 'Mel Gibson Sophie Marceau Patrick McGoohan Angus Macfadyen',
#   'summary': 'Scottish warrior William Wallace leads his countrymen in a rebellion to free his homeland from the tyranny of King Edward I of England'},
#  {'id': 104,
#   'title': 'Reservoir Dogs',
#   'year': '1992',
#   'runtime': 99,
#   'rating': 8.3,
#   'genre': 'Crime Drama Thriller',
#   'actors': 'Harvey Keitel Tim Roth Michael Madsen Chris Penn',
#   'summary': 'When a simple jewelry heist goes horribly wrong the surviving criminals begin to suspect that one of them is a police informant'},
#  {'id': 105,
#   'title': 'Full Metal Jacket',
#   'year': '1987',
#   'runtime': 116,
#   'rating': 8.3,
#   'genre': 'Drama War',
#   'actors': "Matthew Modine R. Lee Ermey Vincent D'Onofrio Adam Baldwin",
#   'summary': 'A pragmatic US Marine observes the dehumanizing effects the Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue'},
#  {'id': 106,
#   'title': 'Idi i smotri',
#   'year': '1985',
#   'runtime': 142,
#   'rating': 8.3,
#   'genre': 'Drama Thriller War',
#   'actors': 'Aleksey Kravchenko Olga Mironova Liubomiras Laucevicius Vladas Bagdonas',
#   'summary': 'After finding an old rifle a young boy joins the Soviet resistance movement against ruthless German forces and experiences the horrors of World War II'},
#  {'id': 107,
#   'title': 'Aliens',
#   'year': '1986',
#   'runtime': 137,
#   'rating': 8.3,
#   'genre': 'Action Adventure Sci-Fi',
#   'actors': 'Sigourney Weaver Michael Biehn Carrie Henn Paul Reiser',
#   'summary': 'Fiftyseven years after surviving an apocalyptic attack aboard her space vessel by merciless space creatures Officer Ripley awakens from hypersleep and tries to warn anyone who will listen about the predators'},
#  {'id': 108,
#   'title': 'Amadeus',
#   'year': '1984',
#   'runtime': 160,
#   'rating': 8.3,
#   'genre': 'Biography Drama History',
#   'actors': 'F. Murray Abraham Tom Hulce Elizabeth Berridge Roy Dotrice',
#   'summary': "The life success and troubles of Wolfgang Amadeus Mozart as told by Antonio Salieri the contemporaneous composer who was insanely jealous of Mozart's talent and claimed to have murdered him"},
#  {'id': 109,
#   'title': 'Scarface',
#   'year': '1983',
#   'runtime': 170,
#   'rating': 8.3,
#   'genre': 'Crime Drama',
#   'actors': 'Al Pacino Michelle Pfeiffer Steven Bauer Mary Elizabeth Mastrantonio',
#   'summary': 'In 1980 Miami a determined Cuban immigrant takes over a drug cartel and succumbs to greed'},
#  {'id': 110,
#   'title': 'Star Wars: Episode VI - Return of the Jedi',
#   'year': '1983',
#   'runtime': 131,
#   'rating': 8.3,
#   'genre': 'Action Adventure Fantasy',
#   'actors': 'Mark Hamill Harrison Ford Carrie Fisher Billy Dee Williams',
#   'summary': "After a daring mission to rescue Han Solo from Jabba the Hutt the Rebels dispatch to Endor to destroy the second Death Star Meanwhile Luke struggles to help Darth Vader back from the dark side without falling into the Emperor's trap"},
#  {'id': 111,
#   'title': 'Das Boot',
#   'year': '1981',
#   'runtime': 149,
#   'rating': 8.3,
#   'genre': 'Adventure Drama Thriller',
#   'actors': 'Jürgen Prochnow Herbert Grönemeyer Klaus Wennemann Hubertus Bengsch',
#   'summary': 'The claustrophobic world of a WWII German Uboat; boredom filth and sheer terror'},
#  {'id': 112,
#   'title': 'Taxi Driver',
#   'year': '1976',
#   'runtime': 114,
#   'rating': 8.3,
#   'genre': 'Crime Drama',
#   'actors': 'Robert De Niro Jodie Foster Cybill Shepherd Albert Brooks',
#   'summary': 'A mentally unstable veteran works as a nighttime taxi driver in New York City where the perceived decadence and sleaze fuels his urge for violent action by attempting to liberate a presidential campaign worker and an underage prostitute'},
#  {'id': 113,
#   'title': 'The Sting',
#   'year': '1973',
#   'runtime': 129,
#   'rating': 8.3,
#   'genre': 'Comedy Crime Drama',
#   'actors': 'Paul Newman Robert Redford Robert Shaw Charles Durning',
#   'summary': 'Two grifters team up to pull off the ultimate con'},
#  {'id': 114,
#   'title': 'A Clockwork Orange',
#   'year': '1971',
#   'runtime': 136,
#   'rating': 8.3,
#   'genre': 'Crime Drama Sci-Fi',
#   'actors': 'Malcolm McDowell Patrick Magee Michael Bates Warren Clarke',
#   'summary': "In the future a sadistic gang leader is imprisoned and volunteers for a conductaversion experiment but it doesn't go as planned"},
#  {'id': 115,
#   'title': '2001: A Space Odyssey',
#   'year': '1968',
#   'runtime': 149,
#   'rating': 8.3,
#   'genre': 'Adventure Sci-Fi',
#   'actors': 'Keir Dullea Gary Lockwood William Sylvester Daniel Richter',
#   'summary': 'After discovering a mysterious artifact buried beneath the Lunar surface mankind sets off on a quest to find its origins with help from intelligent supercomputer HAL 9000'},
#  {'id': 116,
#   'title': 'Per qualche dollaro in più',
#   'year': '1965',
#   'runtime': 132,
#   'rating': 8.3,
#   'genre': 'Western',
#   'actors': 'Clint Eastwood Lee Van Cleef Gian Maria Volontè Mara Krupp',
#   'summary': 'Two bounty hunters with the same intentions team up to track down a Western outlaw'},
#  {'id': 117,
#   'title': 'Lawrence of Arabia',
#   'year': '1962',
#   'runtime': 228,
#   'rating': 8.3,
#   'genre': 'Adventure Biography Drama',
#   'actors': "Peter O'Toole Alec Guinness Anthony Quinn Jack Hawkins",
#   'summary': 'The story of TE Lawrence the English officer who successfully united and led the diverse often warring Arab tribes during World War I in order to fight the Turks'},
#  {'id': 118,
#   'title': 'The Apartment',
#   'year': '1960',
#   'runtime': 125,
#   'rating': 8.3,
#   'genre': 'Comedy Drama Romance',
#   'actors': 'Jack Lemmon Shirley MacLaine Fred MacMurray Ray Walston',
#   'summary': 'A man tries to rise in his company by letting its executives use his apartment for trysts but complications and a romance of his own ensue'},
#  {'id': 119,
#   'title': 'North by Northwest',
#   'year': '1959',
#   'runtime': 136,
#   'rating': 8.3,
#   'genre': 'Adventure Mystery Thriller',
#   'actors': 'Cary Grant Eva Marie Saint James Mason Jessie Royce Landis',
#   'summary': 'A New York City advertising executive goes on the run after being mistaken for a government agent by a group of foreign spies'},
#  {'id': 120,
#   'title': 'Vertigo',
#   'year': '1958',
#   'runtime': 128,
#   'rating': 8.3,
#   'genre': 'Mystery Romance Thriller',
#   'actors': 'James Stewart Kim Novak Barbara Bel Geddes Tom Helmore',
#   'summary': 'A former police detective juggles wrestling with his personal demons and becoming obsessed with a hauntingly beautiful woman'},
#  {'id': 121,
#   'title': "Singin' in the Rain",
#   'year': '1952',
#   'runtime': 103,
#   'rating': 8.3,
#   'genre': 'Comedy Musical Romance',
#   'actors': "Gene Kelly Gene Kelly Donald O'Connor Debbie Reynolds",
#   'summary': 'A silent film production company and cast make a difficult transition to sound'},
#  {'id': 122,
#   'title': 'Ikiru',
#   'year': '1952',
#   'runtime': 143,
#   'rating': 8.3,
#   'genre': 'Drama',
#   'actors': "Takashi Shimura Nobuo Kaneko Shin'ichi Himori Haruo Tanaka",
#   'summary': 'A bureaucrat tries to find a meaning in his life after he discovers he has terminal cancer'},
#  {'id': 123,
#   'title': 'Ladri di biciclette',
#   'year': '1948',
#   'runtime': 89,
#   'rating': 8.3,
#   'genre': 'Drama',
#   'actors': 'Lamberto Maggiorani Enzo Staiola Lianella Carell Elena Altieri',
#   'summary': "In postwar Italy a workingclass man's bicycle is stolen He and his son set out to find it"},
#  {'id': 124,
#   'title': 'Double Indemnity',
#   'year': '1944',
#   'runtime': 107,
#   'rating': 8.3,
#   'genre': 'Crime Drama Film-Noir',
#   'actors': 'Fred MacMurray Barbara Stanwyck Edward G. Robinson Byron Barr',
#   'summary': 'An insurance representative lets himself be talked by a seductive housewife into a murder/insurance fraud scheme that arouses the suspicion of an insurance investigator'},
#  {'id': 125,
#   'title': 'Citizen Kane',
#   'year': '1941',
#   'runtime': 119,
#   'rating': 8.3,
#   'genre': 'Drama Mystery',
#   'actors': 'Orson Welles Joseph Cotten Dorothy Comingore Agnes Moorehead',
#   'summary': "Following the death of publishing tycoon Charles Foster Kane reporters scramble to uncover the meaning of his final utterance; 'Rosebud'"},
#  {'id': 126,
#   'title': 'M - Eine Stadt sucht einen Mörder',
#   'year': '1931',
#   'runtime': 117,
#   'rating': 8.3,
#   'genre': 'Crime Mystery Thriller',
#   'actors': 'Peter Lorre Ellen Widmann Inge Landgut Otto Wernicke',
#   'summary': 'When the police in a German city are unable to catch a childmurderer other criminals join in the manhunt'},
#  {'id': 127,
#   'title': 'Metropolis',
#   'year': '1927',
#   'runtime': 153,
#   'rating': 8.3,
#   'genre': 'Drama Sci-Fi',
#   'actors': 'Brigitte Helm Alfred Abel Gustav Fröhlich Rudolf Klein-Rogge',
#   'summary': "In a futuristic city sharply divided between the working class and the city planners the son of the city's mastermind falls in love with a workingclass prophet who predicts the coming of a savior to mediate their differences"},
#  {'id': 128,
#   'title': 'The Kid',
#   'year': '1921',
#   'runtime': 68,
#   'rating': 8.3,
#   'genre': 'Comedy Drama Family',
#   'actors': 'Charles Chaplin Edna Purviance Jackie Coogan Carl Miller',
#   'summary': 'The Tramp cares for an abandoned child but events put that relationship in jeopardy'},
#  {'id': 129,
#   'title': 'Chhichhore',
#   'year': '2019',
#   'runtime': 143,
#   'rating': 8.2,
#   'genre': 'Comedy Drama',
#   'actors': 'Sushant Singh Rajput Shraddha Kapoor Varun Sharma Prateik',
#   'summary': 'A tragic incident forces Anirudh a middleaged man to take a trip down memory lane and reminisce his college days along with his friends who were labelled as losers'},
#  {'id': 130,
#   'title': 'Uri: The Surgical Strike',
#   'year': '2018',
#   'runtime': 138,
# ...
#   'summary': "Adaptation of James Jones' autobiographical 1962 novel focusing on the conflict at Guadalcanal during the second World War"},
#  {'id': 957,
#   'title': 'Mulan',
#   'year': '1998',
#   'runtime': 88,
#   'rating': 7.6,
#   'genre': 'Animation Adventure Family',
#   'actors': 'Barry Cook Ming-Na Wen Eddie Murphy BD Wong',
#   'summary': "To save her father from death in the army a young maiden secretly goes in his place and becomes one of China's greatest heroines in the process"},
#  {'id': 958,
#   'title': 'Fear and Loathing in Las Vegas',
#   'year': '1998',
#   'runtime': 118,
#   'rating': 7.6,
#   'genre': 'Adventure Comedy Drama',
#   'actors': 'Johnny Depp Benicio Del Toro Tobey Maguire Michael Lee Gogin',
#   'summary': 'An oddball journalist and his psychopathic lawyer travel to Las Vegas for a series of psychedelic escapades'},
#  {'id': 959,
#   'title': 'Funny Games',
#   'year': '1997',
#   'runtime': 108,
#   'rating': 7.6,
#   'genre': 'Crime Drama Thriller',
#   'actors': 'Susanne Lothar Ulrich Mühe Arno Frisch Frank Giering',
#   'summary': 'Two violent young men take a mother father and son hostage in their vacation cabin and force them to play sadistic "games" with one another for their own amusement'},
#  {'id': 960,
#   'title': 'Dark City',
#   'year': '1998',
#   'runtime': 100,
#   'rating': 7.6,
#   'genre': 'Mystery Sci-Fi Thriller',
#   'actors': 'Rufus Sewell Kiefer Sutherland Jennifer Connelly William Hurt',
#   'summary': 'A man struggles with memories of his past which include a wife he cannot remember and a nightmarish world no one else ever seems to wake up from'},
#  {'id': 961,
#   'title': 'Sleepers',
#   'year': '1996',
#   'runtime': 147,
#   'rating': 7.6,
#   'genre': 'Crime Drama Thriller',
#   'actors': 'Robert De Niro Kevin Bacon Brad Pitt Jason Patric',
#   'summary': 'After a prank goes disastrously wrong a group of boys are sent to a detention center where they are brutalized Thirteen years later an unexpected random encounter with a former guard gives them a chance for revenge'},
#  {'id': 962,
#   'title': 'Lost Highway',
#   'year': '1997',
#   'runtime': 134,
#   'rating': 7.6,
#   'genre': 'Mystery Thriller',
#   'actors': 'Bill Pullman Patricia Arquette John Roselius Louis Eppolito',
#   'summary': "Anonymous videotapes presage a musician's murder conviction and a gangster's girlfriend leads a mechanic astray"},
#  {'id': 963,
#   'title': 'Sense and Sensibility',
#   'year': '1995',
#   'runtime': 136,
#   'rating': 7.6,
#   'genre': 'Drama Romance',
#   'actors': 'Emma Thompson Kate Winslet James Fleet Tom Wilkinson',
#   'summary': 'Rich Mr Dashwood dies leaving his second wife and her three daughters poor by the rules of inheritance The two eldest daughters are the title opposites'},
#  {'id': 964,
#   'title': 'Die Hard: With a Vengeance',
#   'year': '1995',
#   'runtime': 128,
#   'rating': 7.6,
#   'genre': 'Action Adventure Thriller',
#   'actors': 'Bruce Willis Jeremy Irons Samuel L. Jackson Graham Greene',
#   'summary': 'John McClane and a Harlem store owner are targeted by German terrorist Simon in New York City where he plans to rob the Federal Reserve Building'},
#  {'id': 965,
#   'title': 'Dead Man',
#   'year': '1995',
#   'runtime': 121,
#   'rating': 7.6,
#   'genre': 'Adventure Drama Fantasy',
#   'actors': 'Johnny Depp Gary Farmer Crispin Glover Lance Henriksen',
#   'summary': 'On the run after murdering a man accountant William Blake encounters a strange aboriginal American man named Nobody who prepares him for his journey into the spiritual world'},
#  {'id': 966,
#   'title': 'The Bridges of Madison County',
#   'year': '1995',
#   'runtime': 135,
#   'rating': 7.6,
#   'genre': 'Drama Romance',
#   'actors': 'Clint Eastwood Meryl Streep Annie Corley Victor Slezak',
#   'summary': 'Photographer Robert Kincaid wanders into the life of housewife Francesca Johnson for four days in the 1960s'},
#  {'id': 967,
#   'title': 'Apollo 13',
#   'year': 'PG',
#   'runtime': 140,
#   'rating': 7.6,
#   'genre': 'Adventure Drama History',
#   'actors': 'Tom Hanks Bill Paxton Kevin Bacon Gary Sinise',
#   'summary': 'NASA must devise a strategy to return Apollo 13 to Earth safely after the spacecraft undergoes massive internal damage putting the lives of the three astronauts on board in jeopardy'},
#  {'id': 968,
#   'title': 'Trois couleurs: Blanc',
#   'year': '1994',
#   'runtime': 92,
#   'rating': 7.6,
#   'genre': 'Comedy Drama Romance',
#   'actors': 'Zbigniew Zamachowski Julie Delpy Janusz Gajos Jerzy Stuhr',
#   'summary': 'After his wife divorces him a Polish immigrant plots to get even with her'},
#  {'id': 969,
#   'title': 'Falling Down',
#   'year': '1993',
#   'runtime': 113,
#   'rating': 7.6,
#   'genre': 'Action Crime Drama',
#   'actors': 'Michael Douglas Robert Duvall Barbara Hershey Rachel Ticotin',
#   'summary': 'An ordinary man frustrated with the various flaws he sees in society begins to psychotically and violently lash out against them'},
#  {'id': 970,
#   'title': 'Dazed and Confused',
#   'year': '1993',
#   'runtime': 102,
#   'rating': 7.6,
#   'genre': 'Comedy',
#   'actors': 'Jason London Wiley Wiggins Matthew McConaughey Rory Cochrane',
#   'summary': 'The adventures of high school and junior high students on the last day of school in May 1976'},
#  {'id': 971,
#   'title': 'My Cousin Vinny',
#   'year': '1992',
#   'runtime': 120,
#   'rating': 7.6,
#   'genre': 'Comedy Crime',
#   'actors': 'Joe Pesci Marisa Tomei Ralph Macchio Mitchell Whitfield',
#   'summary': 'Two New Yorkers accused of murder in rural Alabama while on their way back to college call in the help of one of their cousins a loudmouth lawyer with no trial experience'},
#  {'id': 972,
#   'title': 'Omohide poro poro',
#   'year': '1991',
#   'runtime': 118,
#   'rating': 7.6,
#   'genre': 'Animation Drama Romance',
#   'actors': 'Miki Imai Toshirô Yanagiba Yoko Honna Mayumi Izuka',
#   'summary': 'A twentysevenyearold office worker travels to the countryside while reminiscing about her childhood in Tokyo'},
#  {'id': 973,
#   'title': 'Delicatessen',
#   'year': '1991',
#   'runtime': 99,
#   'rating': 7.6,
#   'genre': 'Comedy Crime',
#   'actors': 'Jean-Pierre Jeunet Marie-Laure Dougnac Dominique Pinon Pascal Benezech',
#   'summary': 'Postapocalyptic surrealist black comedy about the landlord of an apartment building who occasionally prepares a delicacy for his odd tenants'},
#  {'id': 974,
#   'title': 'Home Alone',
#   'year': '1990',
#   'runtime': 103,
#   'rating': 7.6,
#   'genre': 'Comedy Family',
#   'actors': 'Macaulay Culkin Joe Pesci Daniel Stern John Heard',
#   'summary': 'An eightyearold troublemaker must protect his house from a pair of burglars when he is accidentally left home alone by his family during Christmas vacation'},
#  {'id': 975,
#   'title': 'The Godfather: Part III',
#   'year': '1990',
#   'runtime': 162,
#   'rating': 7.6,
#   'genre': 'Crime Drama',
#   'actors': 'Al Pacino Diane Keaton Andy Garcia Talia Shire',
#   'summary': 'Follows Michael Corleone now in his 60s as he seeks to free his family from crime and find a suitable successor to his empire'},
#  {'id': 976,
#   'title': 'When Harry Met Sally...',
#   'year': '1989',
#   'runtime': 95,
#   'rating': 7.6,
#   'genre': 'Comedy Drama Romance',
#   'actors': 'Billy Crystal Meg Ryan Carrie Fisher Bruno Kirby',
#   'summary': 'Harry and Sally have known each other for years and are very good friends but they fear sex would ruin the friendship'},
#  {'id': 977,
#   'title': 'The Little Mermaid',
#   'year': '1989',
#   'runtime': 83,
#   'rating': 7.6,
#   'genre': 'Animation Family Fantasy',
#   'actors': 'John Musker Jodi Benson Samuel E. Wright Rene Auberjonois',
#   'summary': "A mermaid princess makes a Faustian bargain in an attempt to become human and win a prince's love"},
#  {'id': 978,
#   'title': 'The Naked Gun: From the Files of Police Squad!',
#   'year': '1988',
#   'runtime': 85,
#   'rating': 7.6,
#   'genre': 'Comedy Crime',
#   'actors': 'Leslie Nielsen Priscilla Presley O.J. Simpson Ricardo Montalban',
#   'summary': 'Incompetent police Detective Frank Drebin must foil an attempt to assassinate Queen Elizabeth II'},
#  {'id': 979,
#   'title': 'Planes, Trains & Automobiles',
#   'year': '1987',
#   'runtime': 93,
#   'rating': 7.6,
#   'genre': 'Comedy Drama',
#   'actors': 'Steve Martin John Candy Laila Robins Michael McKean',
#   'summary': 'A man must struggle to travel home for Thanksgiving with a lovable oaf of a shower curtain ring salesman as his only companion'},
#  {'id': 980,
#   'title': 'Lethal Weapon',
#   'year': '1987',
#   'runtime': 109,
#   'rating': 7.6,
#   'genre': 'Action Crime Thriller',
#   'actors': 'Mel Gibson Danny Glover Gary Busey Mitchell Ryan',
#   'summary': 'Two newly paired cops who are complete opposites must put aside their differences in order to catch a gang of drug smugglers'},
#  {'id': 981,
#   'title': 'Blood Simple',
#   'year': '1984',
#   'runtime': 99,
#   'rating': 7.6,
#   'genre': 'Crime Drama Thriller',
#   'actors': 'Ethan Coen John Getz Frances McDormand Dan Hedaya',
#   'summary': 'The owner of a seedy smalltown Texas bar discovers that one of his employees is having an affair with his wife A chaotic chain of misunderstandings lies and mischief ensues after he devises a plot to have them murdered'},
#  {'id': 982,
#   'title': 'On Golden Pond',
#   'year': '1981',
#   'runtime': 109,
#   'rating': 7.6,
#   'genre': 'Drama',
#   'actors': 'Katharine Hepburn Henry Fonda Jane Fonda Doug McKeon',
#   'summary': "Norman is a curmudgeon with an estranged relationship with his daughter Chelsea At Golden Pond he and his wife nevertheless agree to care for Billy the son of Chelsea's new boyfriend and a most unexpected relationship blooms"},
#  {'id': 983,
#   'title': 'Mad Max 2',
#   'year': '1981',
#   'runtime': 96,
#   'rating': 7.6,
#   'genre': 'Action Adventure Sci-Fi',
#   'actors': 'Mel Gibson Bruce Spence Michael Preston Max Phipps',
#   'summary': 'In the postapocalyptic Australian wasteland a cynical drifter agrees to help a small gasolinerich community escape a horde of bandits'},
#  {'id': 984,
#   'title': 'The Warriors',
#   'year': '1979',
#   'runtime': 92,
#   'rating': 7.6,
#   'genre': 'Action Crime Thriller',
#   'actors': 'Michael Beck James Remar Dorsey Wright Brian Tyler',
#   'summary': 'In the near future a charismatic leader summons the street gangs of New York City in a bid to take it over When he is killed The Warriors are falsely blamed and now must fight their way home while every other gang is hunting them down'},
#  {'id': 985,
#   'title': 'The Muppet Movie',
#   'year': '1979',
#   'runtime': 95,
#   'rating': 7.6,
#   'genre': 'Adventure Comedy Family',
#   'actors': 'Jim Henson Frank Oz Jerry Nelson Richard Hunt',
#   'summary': 'Kermit and his newfound friends trek across America to find success in Hollywood but a frog legs merchant is after Kermit'},
#  {'id': 986,
#   'title': 'Escape from Alcatraz',
#   'year': '1979',
#   'runtime': 112,
#   'rating': 7.6,
#   'genre': 'Action Biography Crime',
#   'actors': 'Clint Eastwood Patrick McGoohan Roberts Blossom Jack Thibeau',
#   'summary': 'Alcatraz is the most secure prison of its time It is believed that no one can ever escape from it until three daring men make a possible successful attempt at escaping from one of the most infamous prisons in the world'},
#  {'id': 987,
#   'title': 'Watership Down',
#   'year': '1978',
#   'runtime': 91,
#   'rating': 7.6,
#   'genre': 'Animation Adventure Drama',
#   'actors': 'John Hubley John Hurt Richard Briers Ralph Richardson',
#   'summary': 'Hoping to escape destruction by human developers and save their community a colony of rabbits led by Hazel and Fiver seek out a safe place to set up a new warren'},
#  {'id': 988,
#   'title': 'Midnight Express',
#   'year': '1978',
#   'runtime': 121,
#   'rating': 7.6,
#   'genre': 'Biography Crime Drama',
#   'actors': 'Brad Davis Irene Miracle Bo Hopkins Paolo Bonacelli',
#   'summary': 'Billy Hayes an American college student is caught smuggling drugs out of Turkey and thrown into prison'},
#  {'id': 989,
#   'title': 'Close Encounters of the Third Kind',
#   'year': '1977',
#   'runtime': 138,
#   'rating': 7.6,
#   'genre': 'Drama Sci-Fi',
#   'actors': 'Richard Dreyfuss François Truffaut Teri Garr Melinda Dillon',
#   'summary': 'Roy Neary an electric lineman watches how his quiet and ordinary daily life turns upside down after a close encounter with a UFO'},
#  {'id': 990,
#   'title': 'The Long Goodbye',
#   'year': '1973',
#   'runtime': 112,
#   'rating': 7.6,
#   'genre': 'Comedy Crime Drama',
#   'actors': 'Elliott Gould Nina van Pallandt Sterling Hayden Mark Rydell',
#   'summary': "Private investigator Philip Marlowe helps a friend out of a jam but in doing so gets implicated in his wife's murder"},
#  {'id': 991,
#   'title': 'Giù la testa',
#   'year': '1971',
#   'runtime': 157,
#   'rating': 7.6,
#   'genre': 'Drama War Western',
#   'actors': 'Rod Steiger James Coburn Romolo Valli Maria Monti',
#   'summary': 'A lowlife bandit and an IRA explosives expert rebel against the government and become heroes of the Mexican Revolution'},
#  {'id': 992,
#   'title': "Kelly's Heroes",
#   'year': '1970',
#   'runtime': 144,
#   'rating': 7.6,
#   'genre': 'Adventure Comedy War',
#   'actors': "Clint Eastwood Telly Savalas Don Rickles Carroll O'Connor",
#   'summary': 'A group of US soldiers sneaks across enemy lines to get their hands on a secret stash of Nazi treasure'},
#  {'id': 993,
#   'title': 'The Jungle Book',
#   'year': '1967',
#   'runtime': 78,
#   'rating': 7.6,
#   'genre': 'Animation Adventure Family',
#   'actors': 'Phil Harris Sebastian Cabot Louis Prima Bruce Reitherman',
#   'summary': 'Bagheera the Panther and Baloo the Bear have a difficult time trying to convince a boy to leave the jungle for human civilization'},
#  {'id': 994,
#   'title': 'Blowup',
#   'year': '1966',
#   'runtime': 111,
#   'rating': 7.6,
#   'genre': 'Drama Mystery Thriller',
#   'actors': 'David Hemmings Vanessa Redgrave Sarah Miles John Castle',
#   'summary': 'A fashion photographer unknowingly captures a death on film after following two lovers in a park'},
#  {'id': 995,
#   'title': "A Hard Day's Night",
#   'year': '1964',
#   'runtime': 87,
#   'rating': 7.6,
#   'genre': 'Comedy Music Musical',
#   'actors': 'John Lennon Paul McCartney George Harrison Ringo Starr',
#   'summary': 'Over two "typical" days in the life of The Beatles the boys struggle to keep themselves and Sir Paul McCartney\'s mischievous grandfather in check while preparing for a live television performance'},
#  {'id': 996,
#   'title': "Breakfast at Tiffany's",
#   'year': '1961',
#   'runtime': 115,
#   'rating': 7.6,
#   'genre': 'Comedy Drama Romance',
#   'actors': 'Audrey Hepburn George Peppard Patricia Neal Buddy Ebsen',
#   'summary': 'A young New York socialite becomes interested in a young man who has moved into her apartment building but her past threatens to get in the way'},
#  {'id': 997,
#   'title': 'Giant',
#   'year': '1956',
#   'runtime': 201,
#   'rating': 7.6,
#   'genre': 'Drama Western',
#   'actors': 'Elizabeth Taylor Rock Hudson James Dean Carroll Baker',
#   'summary': 'Sprawling epic covering the life of a Texas cattle rancher and his family and associates'},
#  {'id': 998,
#   'title': 'From Here to Eternity',
#   'year': '1953',
#   'runtime': 118,
#   'rating': 7.6,
#   'genre': 'Drama Romance War',
#   'actors': 'Burt Lancaster Montgomery Clift Deborah Kerr Donna Reed',
#   'summary': "In Hawaii in 1941 a private is cruelly punished for not boxing on his unit's team while his captain's wife and secondincommand are falling in love"},
#  {'id': 999,
#   'title': 'Lifeboat',
#   'year': '1944',
#   'runtime': 97,
#   'rating': 7.6,
#   'genre': 'Drama War',
#   'actors': 'Tallulah Bankhead John Hodiak Walter Slezak William Bendix',
#   'summary': 'Several survivors of a torpedoed merchant ship in World War II find themselves in the same lifeboat with one of the crew members of the Uboat that sank their ship'},
#  {'id': 1000,
#   'title': 'The 39 Steps',
#   'year': '1935',
#   'runtime': 86,
#   'rating': 7.6,
#   'genre': 'Crime Mystery Thriller',
#   'actors': 'Robert Donat Madeleine Carroll Lucie Mannheim Godfrey Tearle',
#   'summary': 'A man in London tries to help a counterespionage Agent But when the Agent is killed and the man stands accused he must go on the run to save himself and stop a spy ring which is trying to steal top secret information'}]
